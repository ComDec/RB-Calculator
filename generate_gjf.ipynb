# %%
import pickle
with open('gaussian_data.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
def mol_to_xyz(mol, file_path="mol.xyz"):
    num_atoms = mol.GetNumAtoms()
    xyz_content = f"{num_atoms}\n\n"
    conf = mol.GetConformer()
    for atom in mol.GetAtoms():
        pos = conf.GetAtomPosition(atom.GetIdx())
        xyz_content += f"{atom.GetSymbol()} {pos.x:.6f} {pos.y:.6f} {pos.z:.6f}\n"
    with open(file_path, 'w+') as f:
        f.write(xyz_content)

# %%
import openbabel
from rdkit import Chem
from rdkit.Chem import AllChem

def xyz_to_sdf_to_mol(xyz_file, sdf_file="temp.sdf"):
    

    obConversion = openbabel.OBConversion()
    obConversion.SetInAndOutFormats("xyz", "sdf")
    mol = openbabel.OBMol()
    if not obConversion.ReadFile(mol, xyz_file):
        raise FileNotFoundError(f"Unable read xyz: {xyz_file}")

    obConversion.WriteFile(mol, sdf_file)
    rdkit_mol = Chem.SDMolSupplier(sdf_file)[0]
    if rdkit_mol is None:
        raise ValueError("convertion error")

    return rdkit_mol

def gjf_to_sdf_to_mol(gjf_file, sdf_file="temp.sdf"):
    

    obConversion = openbabel.OBConversion()
    obConversion.SetInAndOutFormats("gjf", "sdf")
    mol = openbabel.OBMol()
    if not obConversion.ReadFile(mol, gjf_file):
        raise FileNotFoundError(f"Unable read gjf: {gjf_file}")

    obConversion.WriteFile(mol, sdf_file)
    rdkit_mol = Chem.SDMolSupplier(sdf_file)[0]
    if rdkit_mol is None:
        raise ValueError("convertion error")

    return rdkit_mol

def get_adjacent_atoms(mol, atom_index):
    atom = mol.GetAtomWithIdx(atom_index)  # 获取指定索引的原子
    adjacent_atoms = [nbr.GetIdx() for nbr in atom.GetNeighbors()]  # 获取所有邻接原子的索引
    return adjacent_atoms

# %%
def draw_xyz(xyz_path):
    mol = xyz_to_sdf_to_mol(xyz_path)
    from rdkit import Chem
    from rdkit.Chem.Draw import rdMolDraw2D
    from IPython.display import SVG
    d2d = rdMolDraw2D.MolDraw2DSVG(350,300)
    d2d.drawOptions().addAtomIndices=True
    d2d.DrawMolecule(mol)
    d2d.FinishDrawing()
    SVG(d2d.GetDrawingText())
    
    return mol

def draw_gjf(xyz_path):
    mol = gjf_to_sdf_to_mol(xyz_path)
    from rdkit import Chem
    from rdkit.Chem.Draw import rdMolDraw2D
    from IPython.display import SVG
    d2d = rdMolDraw2D.MolDraw2DSVG(350,300)
    d2d.drawOptions().addAtomIndices=True
    d2d.DrawMolecule(mol)
    d2d.FinishDrawing()
    SVG(d2d.GetDrawingText())
    
    return mol

# %%
import os
from rdkit import Chem
from rdkit.Chem import AllChem

def mol_to_gjf(mol, atom1, atom2, gjf_path, nproc=64, memory=512, chk="temp.chk"):
    
    if atom1 > atom2:
        atom1, atom2 = atom2, atom1
    
    xyz_filename = "__temp__.xyz"
    
    mol.UpdatePropertyCache(strict=True)
    mol = Chem.AddHs(mol)
    AllChem.EmbedMolecule(mol, randomSeed=42)
    AllChem.UFFOptimizeMolecule(mol)

    # 创建XYZ文件
    mol_to_xyz(mol, "__temp__.xyz")
    
    # 使用Open Babel将XYZ转换为GJF
    temp_gjf_filename = "__temp__.gjf"
    temp_sdf_filename = "__temp__.sdf"
    
    command = f"obabel -ixyz {xyz_filename} -o gjf -xk \"#p M062X def2svp opt=modredundant nosymm\" > {temp_gjf_filename}"
    os.system(command)
    
    command = f"obabel -ixyz {xyz_filename} -o sdf > {temp_sdf_filename}"
    os.system(command)
    
    mol_with_bond = Chem.SDMolSupplier(temp_sdf_filename)[0]
    
    atom1_adjs = get_adjacent_atoms(mol_with_bond, atom1)
    atom1_adjs.remove(atom2)
    
    atom2_adjs = get_adjacent_atoms(mol_with_bond, atom2)
    atom2_adjs.remove(atom1)
    
    assert len(atom1_adjs) >=1 and len(atom2_adjs) >= 1, "atom1 and atom2 lay in the terminal of the molecule"
    
    atom1_adj = atom1_adjs[0]
    atom2_adj = atom2_adjs[0]
    
    # 读取转换后的GJF文件
    with open(temp_gjf_filename, "r") as file:
        gjf_lines = file.readlines()
    
    # 准备最终的GJF文件
    final_gjf_filename = gjf_path
    with open(final_gjf_filename, "w") as file:
        file.write(f"%nprocshared={nproc}\n")
        file.write(f"%mem={memory}GB\n")
        file.write(f"%chk={chk}\n")
        file.write(gjf_lines[0] + "\n")
        file.write("Title Card Required\n\n")
        for line in gjf_lines[4:]:
            file.write(line)
        
        # 添加柔性扫描命令
        file.write(f"{atom1_adj} {atom1} {atom2} {atom2_adj} S 36 10.0\n")
        file.write("\n"*2)
    
    # 清理临时文件
    os.remove(xyz_filename)
    os.remove(temp_sdf_filename)
    os.remove(temp_gjf_filename)
    
    return mol_with_bond

# %%
for index, mol in enumerate(data["mol"]):
    gjf_path = os.path.join("gaussian_3k", f"{index}.gjf")
    atom1, atom2 = data["axis_index"][index]
    try:
        _ = mol_to_gjf(mol, atom1, atom2, gjf_path, nproc=64, memory=512, chk=f"temp_{index}.chk")
    except:
        continue
# Out:
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:05:32] Explicit valence for atom # 6 N, 4, is greater than permitted
# [20:05:32] ERROR: Could not sanitize molecule ending on line 46
# [20:05:32] ERROR: Explicit valence for atom # 6 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:05:43] Explicit valence for atom # 3 N, 4, is greater than permitted
# [20:05:43] ERROR: Could not sanitize molecule ending on line 56
# [20:05:43] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:05:46] Explicit valence for atom # 4 N, 4, is greater than permitted
# [20:05:46] ERROR: Could not sanitize molecule ending on line 58
# [20:05:46] ERROR: Explicit valence for atom # 4 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:05:52] Explicit valence for atom # 2 N, 4, is greater than permitted
# [20:05:52] ERROR: Could not sanitize molecule ending on line 72
# [20:05:52] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:05:54] Explicit valence for atom # 2 N, 4, is greater than permitted
# [20:05:54] ERROR: Could not sanitize molecule ending on line 58
# [20:05:54] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:05:55] Explicit valence for atom # 3 N, 4, is greater than permitted
# [20:05:55] ERROR: Could not sanitize molecule ending on line 58
# [20:05:55] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:05:58] Explicit valence for atom # 3 N, 4, is greater than permitted
# [20:05:58] ERROR: Could not sanitize molecule ending on line 58
# [20:05:58] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:06:00] Explicit valence for atom # 1 N, 4, is greater than permitted
# [20:06:00] ERROR: Could not sanitize molecule ending on line 52
# [20:06:00] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:06:00] Explicit valence for atom # 5 N, 4, is greater than permitted
# [20:06:00] ERROR: Could not sanitize molecule ending on line 60
# [20:06:00] ERROR: Explicit valence for atom # 5 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:06:07] Explicit valence for atom # 2 N, 4, is greater than permitted
# [20:06:07] ERROR: Could not sanitize molecule ending on line 58
# [20:06:07] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:06:13] Explicit valence for atom # 1 N, 4, is greater than permitted
# [20:06:13] ERROR: Could not sanitize molecule ending on line 70
# [20:06:13] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:06:17] Explicit valence for atom # 1 N, 4, is greater than permitted
# [20:06:17] ERROR: Could not sanitize molecule ending on line 60
# [20:06:17] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:06:18] Explicit valence for atom # 2 N, 4, is greater than permitted
# [20:06:18] ERROR: Could not sanitize molecule ending on line 54
# [20:06:18] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ...
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:08:32] Explicit valence for atom # 0 N, 4, is greater than permitted
# [20:08:32] ERROR: Could not sanitize molecule ending on line 98
# [20:08:32] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:08:34] Explicit valence for atom # 1 N, 4, is greater than permitted
# [20:08:34] ERROR: Could not sanitize molecule ending on line 67
# [20:08:34] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:08:39] Explicit valence for atom # 4 N, 4, is greater than permitted
# [20:08:39] ERROR: Could not sanitize molecule ending on line 56
# [20:08:39] ERROR: Explicit valence for atom # 4 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is __temp__.xyz)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:08:43] Explicit valence for atom # 3 N, 4, is greater than permitted
# [20:08:43] ERROR: Could not sanitize molecule ending on line 66
# [20:08:43] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [20:08:47] Explicit valence for atom # 0 N, 4, is greater than permitted
# [20:08:47] ERROR: Could not sanitize molecule ending on line 60
# [20:08:47] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
